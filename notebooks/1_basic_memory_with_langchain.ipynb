# %%
from dotenv import load_dotenv
load_dotenv()

from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-5.6")

prompts = [
    {"role": "user", "content": "Hello, My name is Amit Kumar."},
    {"role": "assistant", "content": "Hello Amit Kumar! How can I assist you today?"},
    {"role": "user", "content": "What is my name?"}   
]
history = []

while True:
    user_input = input('User:')
    if user_input.lower() in ['exit', 'quit', 'bye']:
        break

    history.append({"role": "user", "content": user_input})
    print('User: ', user_input, '\n')
   
    response = llm.invoke(history)
    history.append({"role": "assistant", "content": response.content})

    print('AI: ', response.content, '\n')
# Out:
# User:  Who is the PM of india ?
#
# AI:  The Prime Minister of India is **Narendra Modi**. He has served since **26 May 2014**.
#
# User:  whais is his age
#
# AI:  Narendra Modi is **75 years old**. He was born on **17 September 1950**.
