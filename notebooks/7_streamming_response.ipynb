# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI

# Load environment variables (GROQ_API_KEY) from .env file
load_dotenv()

# Initialize the ChatGroq model with a supported model ID
llm = ChatOpenAI(model="gpt-4")

response = llm.stream("Can you cexplain me GEN-AI ? ")

for chunk in response:
    print(chunk.content, end="", flush=True)
#print(response)
# Out:
# GEN-AI, short for Genetic Artificial Intelligence, refers to a type of AI that uses genetic algorithms to improve and evolve over time. Like biological evolution, GEN-AI systems use a process of trial and error, mutation, selection and cross-over to make themselves smarter.
#
# The goal of GEN-AI is to create systems that can adapt to new situations and solve complex, unpredictable problems without human intervention. This is done by mimicking the process of natural selection, where the strongest and most adaptable individuals (or in this case, algorithms) are the ones that survive and pass their traits onto the next generation.
#
# In GEN-AI, a population of AI models is trained on a problem. Each model in the population is then evaluated based on its performance. The best performing models are selected and used to generate the next generation of models, through a process similar to genetic cross-over and mutation. This cycle is repeated until an optimal model is found.
#
# ...

# %%
from langchain_groq import ChatGroq
llm = ChatGroq(model="llama-3.3-70b-versatile")

response = llm.stream("Can you cexplain me GEN-AI ? ")

for chunk in response:
    print(chunk.content, end="", flush=True)
# Out:
# GEN-AI stands for General Artificial Intelligence. It refers to a type of artificial intelligence that is capable of performing any intellectual task that a human can. GEN-AI is often considered the "holy grail" of artificial intelligence research, as it has the potential to revolutionize numerous fields and industries.
#
# The key characteristics of GEN-AI include:
#
# 1. **Reasoning and Problem-Solving**: GEN-AI can reason, solve problems, and make decisions like a human.
# 2. **Knowledge Representation**: GEN-AI can represent and understand knowledge in a way that is similar to human cognition.
# 3. **Learning and Adaptation**: GEN-AI can learn from experience, adapt to new situations, and improve its performance over time.
# 4. **Common Sense**: GEN-AI has a deep understanding of the world, including social norms, ethics, and human values.
# 5. **Autonomy**: GEN-AI can operate independently, making decisions and taking actions without human intervention.
#
# ...
