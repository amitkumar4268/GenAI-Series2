# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_community.utilities import GoogleSerperAPIWrapper
from langchain_groq import ChatGroq
from langchain.agents import create_agent

# %%
model = ChatGroq(model="openai/gpt-oss-20b")
search = GoogleSerperAPIWrapper()

#search.run("What is the capital of India?")
# Out:
# 'New Delhi is the capital city of India and a part of the National Capital Territory of Delhi (NCT). New Delhi is the seat of all three branches of the ... New Delhi became the capital of India in 1931. But how did it all happen? Before Delhi, the capital of British India was Calcutta, now Kolkata. Delhi became the capital after Mughal sultan moved it from Agra (where the Taj Mahal is). British did build the modern "Lutyens" Delhi but Old ... What\'s The Capital Of India? Pt.346. This content isn\'t available. Skip video But the Indian constitution itself merely declares the capital to be the “National Capital Territory of Delhi” (239AA), and subsequently refers ... New Delhi is the capital city of India and part of the National Capital Territory of Delhi, serving as the seat of all three branches of the Government of ... New Delhi is the national capital of India. has been the capital of India since 1947. Delhi, a city and union territory, is the national ... From its origins as \'Indraprastha\' in the Mahabharata to becoming the capital in 1911, Delhi blends ancient charm and modern governance.'

# %%
agent = create_agent(
    model=model, 
    tools=[search.run],
    system_prompt="You are a helpful assistant and you can search for any question on google."
)

question = "Who won the women's world cup 2025?"
response = agent.invoke({"messages": [{"role": "user", "content": question}]})
print(response["messages"][-1].content)
# Out:
# I’m not sure which “women’s World Cup” you’re referring to—there are several major tournaments in 2025 (e.g., ICC Women’s Cricket World Cup, FIFA Women’s World Cup, etc.). Could you let me know which sport you’re asking about?
